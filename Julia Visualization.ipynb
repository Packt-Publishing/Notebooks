# %%
using Gadfly
srand(111)
plot(x=rand(7), y=rand(7))
# Out:
# Plot(...)

# %%
using Gadfly
srand(111)
plot(x=rand(113), Geom.histogram(bincount=10))
# Out:
# Plot(...)

# %%
using Winston

# %%
srand(111)
# Out:
# MersenneTwister(UInt32[0x0000006f],Base.dSFMT.DSFMT_state(Int32[-1742434217,1072888606,-1808167675,1073264677,-816900598,1073279215,-1688324199,1073349469,966630521,1072721743  …  -182202980,1073352782,-336987111,1073634920,293846579,-2027139531,-1236354088,-20277153,382,0]),[1.39039,1.48536,1.51927,1.05793,1.84529,1.26453,1.93829,1.5337,1.0981,1.99852  …  1.8856,1.89475,1.50018,1.50049,1.15113,1.0611,1.81883,1.33218,1.16599,1.11652],382)

# %%
pl = plot(cumsum(rand(100) .-0.5), "g", cumsum(rand(100) .- 0.5), "b")
# Out:
# MethodError: no method matching plot(::Array{Float64,1}, ::String, ::Array{Float64,1}, ::String)

# %%
srand(111)

pl = plot(cumsum(rand(100) .- 0.5), c"g", cumsum(rand(100) .- 0.5), "b")

display(pl)
# Out:
# MethodError: no method matching plot(::Array{Float64,1}, ::String, ::Array{Float64,1}, ::String)
